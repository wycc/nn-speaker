# %% [markdown]
# # Prepare audio data for image recognition
#
# The data is pretty good, but there's a few samples that aren't exactly 1 second long and some samples that are either truncated or don't contain very much of the word.
#
# The code in the notebook attempts to filter out the broken audio so that we are only using good audio.
#
# We then generate spectrograms of each word. We mix in background noise with the words to make it a more realistic audio sample.

# %% [markdown]
# ## Download data set
# Download from: https://storage.cloud.google.com/download.tensorflow.org/data/speech_commands_v0.02.tar.gz - approx 2.3 GB
#
# And then run
# ```
# tar -xzf data_speech_commands_v0.02.tar.gz -C speech_data
# ```

# %%
import tensorflow as tf
import numpy as np
from tensorflow.io import gfile
from tensorflow.python.ops import gen_audio_ops as audio_ops
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import scipy.io.wavfile as wavfile

# %%
import psutil, os


def mem(label=""):
    p = psutil.Process(os.getpid())
    gb = p.memory_info().rss / 1024**3
    print(f"[記憶體] {label}: {gb:.2f} GB")

# %%
SPEECH_DATA = "speech_data"

# %%
# The audio is all sampled at 16KHz and should all be 1 second in length - so 1 second is 16000 samples
EXPECTED_SAMPLES = 16000
# Noise floor to detect if any audio is present
NOISE_FLOOR = 0.1
# How many samples should be abover the noise floor?
MINIMUM_VOICE_LENGTH = EXPECTED_SAMPLES / 4

# %%
# list of folders we want to process in the speech_data folder
from tensorflow.python.ops import gen_audio_ops as audio_ops

words = [
    "backward",
    "bed",
    "bird",
    "cat",
    "dog",
    "down",
    "eight",
    "five",
    "follow",
    "forward",
    "four",
    "go",
    "happy",
    "house",
    "learn",
    "left",
    "marvin",
    "nine",
    "no",
    "off",
    "on",
    "one",
    "right",
    "seven",
    "sheila",
    "six",
    "stop",
    "three",
    "tree",
    "two",
    "up",
    "visual",
    "wow",
    "yes",
    "zero",
    "_background",
]

# %%
def get_files(word):
    return gfile.glob(SPEECH_DATA + "/" + word + "/*.wav")


def load_wav(file_path):
    try:
        rate, data = wavfile.read(file_path)
    except Exception:
        return None
    if data.ndim > 1:
        data = data[:, 0]
    data = data.astype(np.float32)
    if len(data) == 0 or np.max(np.abs(data)) == 0:
        return None
    return data


def get_voice_position(audio, noise_floor):
    audio = audio - np.mean(audio)
    peak = np.max(np.abs(audio))
    if peak == 0:
        return 0, len(audio)
    audio = audio / peak
    mask = np.abs(audio) > noise_floor
    indices = np.where(mask)[0]
    if len(indices) == 0:
        return 0, len(audio)
    return int(indices[0]), int(indices[-1] + 1)


def get_voice_length(audio, noise_floor):
    start, end = get_voice_position(audio, noise_floor)
    return end - start


def is_voice_present(audio, noise_floor, required_length):
    return get_voice_length(audio, noise_floor) >= required_length


def is_correct_length(audio, expected_length):
    return len(audio) == expected_length


def is_valid_file(file_name):
    audio = load_wav(file_name)
    if audio is None or not is_correct_length(audio, EXPECTED_SAMPLES):
        return False
    audio = audio - np.mean(audio)
    peak = np.max(np.abs(audio))
    if peak == 0:
        return False
    audio = audio / peak
    return is_voice_present(audio, NOISE_FLOOR, MINIMUM_VOICE_LENGTH)

# %%
def get_spectrogram(audio):
    audio = np.array(audio).flatten()
    audio = audio - np.mean(audio)
    peak = np.max(np.abs(audio))
    if peak > 0:
        audio = audio / peak
    audio_tensor = tf.constant(
        np.reshape(audio, (EXPECTED_SAMPLES, 1)), dtype=tf.float32
    )
    spectrogram = audio_ops.audio_spectrogram(
        audio_tensor, window_size=320, stride=160, magnitude_squared=True
    ).numpy()
    spectrogram = tf.nn.pool(
        input=tf.expand_dims(spectrogram, -1),
        window_shape=[1, 6],
        strides=[1, 6],
        pooling_type="AVG",
        padding="SAME",
    )
    spectrogram = tf.squeeze(spectrogram, axis=0)
    spectrogram = np.log10(spectrogram + 1e-6)
    return spectrogram

# %%
def process_file(file_path):
    audio = load_wav(file_path)
    if audio is None:
        return None
    audio = audio - np.mean(audio)
    peak = np.max(np.abs(audio))
    if peak > 0:
        audio = audio / peak

    voice_start, voice_end = get_voice_position(audio, NOISE_FLOOR)
    end_gap = len(audio) - voice_end
    random_offset = int(np.random.uniform(0, max(1, voice_start + end_gap)))
    audio = np.roll(audio, -random_offset + end_gap)

    background_volume = np.random.uniform(0, 0.1)
    background_files = get_files("_background_noise_")
    background_file = np.random.choice(background_files)
    background = load_wav(background_file)
    if background is not None and len(background) >= EXPECTED_SAMPLES:
        bg_start = np.random.randint(0, len(background) - EXPECTED_SAMPLES)
        bg = background[bg_start : bg_start + EXPECTED_SAMPLES].astype(np.float32)
        bg = bg - np.mean(bg)
        bg_peak = np.max(np.abs(bg))
        if bg_peak > 0:
            bg = bg / bg_peak
        audio = audio + background_volume * bg

    return get_spectrogram(audio)

# %%
train = []
validate = []
test = []

TRAIN_SIZE = 0.8
VALIDATION_SIZE = 0.1
TEST_SIZE = 0.1

# %%
def process_files(file_names, label, repeat=1):
    file_names = tf.repeat(file_names, repeat).numpy()
    return [
        (process_file(file_name), label)
        for file_name in tqdm(file_names, desc=f"{word} ({label})", leave=False)
    ]


# process the files for a word into the spectrogram and one hot encoding word value
def process_word(word, repeat=1):
    # the index of the word word we are processing
    label = words.index(word)
    # get a list of files names for the word
    file_names = [
        file_name
        for file_name in tqdm(get_files(word), desc="Checking", leave=False)
        if is_valid_file(file_name)
    ]
    # randomly shuffle the filenames
    np.random.shuffle(file_names)
    # split the files into train, validate and test buckets
    train_size = int(TRAIN_SIZE * len(file_names))
    validation_size = int(VALIDATION_SIZE * len(file_names))
    test_size = int(TEST_SIZE * len(file_names))
    # get the training samples
    train.extend(process_files(file_names[:train_size], label, repeat=repeat))
    # and the validation samples
    validate.extend(
        process_files(
            file_names[train_size : train_size + validation_size], label, repeat=repeat
        )
    )
    # and the test samples
    test.extend(
        process_files(file_names[train_size + validation_size :], label, repeat=repeat)
    )


from tqdm.notebook import tqdm

# process all the words and all the files
for word in tqdm(words, desc="Processing words"):
    if "_" not in word:
        # add more examples of yes to balance our training set
        repeat = 70 if word == "yes" else 1
        process_word(word, repeat=repeat)

print(len(train), len(test), len(validate))
# Out:
# Processing words:   0%|          | 0/36 [00:00<?, ?it/s]
# Checking:   0%|          | 0/1664 [00:00<?, ?it/s]
# 2026-04-20 16:26:27.221032: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2026-04-20 16:26:27.221222: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-04-20 16:26:27.221239: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2026-04-20 16:26:27.221443: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-04-20 16:26:27.221777: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# backward (0):   0%|          | 0/1228 [00:00<?, ?it/s]
# /var/folders/9p/vrw0b6x5165fzcr_7p_j6b1r0000gp/T/ipykernel_54095/474903418.py:7: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   rate, data = wavfile.read(file_path)
# backward (0):   0%|          | 0/153 [00:00<?, ?it/s]
# backward (0):   0%|          | 0/154 [00:00<?, ?it/s]
# Checking:   0%|          | 0/2014 [00:00<?, ?it/s]
# bed (1):   0%|          | 0/1064 [00:00<?, ?it/s]
# bed (1):   0%|          | 0/133 [00:00<?, ?it/s]
# bed (1):   0%|          | 0/133 [00:00<?, ?it/s]
# Checking:   0%|          | 0/2064 [00:00<?, ?it/s]
# bird (2):   0%|          | 0/1318 [00:00<?, ?it/s]
# bird (2):   0%|          | 0/164 [00:00<?, ?it/s]
# bird (2):   0%|          | 0/166 [00:00<?, ?it/s]
# Checking:   0%|          | 0/2031 [00:00<?, ?it/s]
# cat (3):   0%|          | 0/975 [00:00<?, ?it/s]
# cat (3):   0%|          | 0/121 [00:00<?, ?it/s]
# cat (3):   0%|          | 0/123 [00:00<?, ?it/s]
# Checking:   0%|          | 0/2128 [00:00<?, ?it/s]
# dog (4):   0%|          | 0/1338 [00:00<?, ?it/s]
# dog (4):   0%|          | 0/167 [00:00<?, ?it/s]
# dog (4):   0%|          | 0/168 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3917 [00:00<?, ?it/s]
# down (5):   0%|          | 0/2686 [00:00<?, ?it/s]
# down (5):   0%|          | 0/335 [00:00<?, ?it/s]
# down (5):   0%|          | 0/337 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3787 [00:00<?, ?it/s]
# eight (6):   0%|          | 0/1936 [00:00<?, ?it/s]
# eight (6):   0%|          | 0/242 [00:00<?, ?it/s]
# eight (6):   0%|          | 0/243 [00:00<?, ?it/s]
# Checking:   0%|          | 0/4052 [00:00<?, ?it/s]
# five (7):   0%|          | 0/2467 [00:00<?, ?it/s]
# five (7):   0%|          | 0/308 [00:00<?, ?it/s]
# five (7):   0%|          | 0/309 [00:00<?, ?it/s]
# Checking:   0%|          | 0/1579 [00:00<?, ?it/s]
# follow (8):   0%|          | 0/1084 [00:00<?, ?it/s]
# follow (8):   0%|          | 0/135 [00:00<?, ?it/s]
# follow (8):   0%|          | 0/137 [00:00<?, ?it/s]
# Checking:   0%|          | 0/1557 [00:00<?, ?it/s]
# forward (9):   0%|          | 0/1124 [00:00<?, ?it/s]
# forward (9):   0%|          | 0/140 [00:00<?, ?it/s]
# forward (9):   0%|          | 0/141 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3728 [00:00<?, ?it/s]
# four (10):   0%|          | 0/2328 [00:00<?, ?it/s]
# four (10):   0%|          | 0/291 [00:00<?, ?it/s]
# four (10):   0%|          | 0/291 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3880 [00:00<?, ?it/s]
# go (11):   0%|          | 0/2245 [00:00<?, ?it/s]
# go (11):   0%|          | 0/280 [00:00<?, ?it/s]
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/site-packages/tqdm/_monitor.py", line 84, in run
#     instance.refresh(nolock=True)
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/site-packages/tqdm/std.py", line 1347, in refresh
#     self.display()
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/site-packages/tqdm/notebook.py", line 171, in display
#     rtext.value = right
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/site-packages/traitlets/traitlets.py", line 716, in __set__
#     self.set(obj, value)
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/site-packages/traitlets/traitlets.py", line 706, in set
#     obj._notify_trait(self.name, old_value, new_value)
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/site-packages/traitlets/traitlets.py", line 1513, in _notify_trait
#     self.notify_change(
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/site-packages/ipykernel/comm/comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#   File "/Users/ruby/yes/envs/DL3.10/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
# LookupError: <ContextVar name='shell_parent' at 0x1195aba10>
# go (11):   0%|          | 0/282 [00:00<?, ?it/s]
# Checking:   0%|          | 0/2054 [00:00<?, ?it/s]
# happy (12):   0%|          | 0/1324 [00:00<?, ?it/s]
# happy (12):   0%|          | 0/165 [00:00<?, ?it/s]
# happy (12):   0%|          | 0/167 [00:00<?, ?it/s]
# Checking:   0%|          | 0/2113 [00:00<?, ?it/s]
# house (13):   0%|          | 0/1164 [00:00<?, ?it/s]
# house (13):   0%|          | 0/145 [00:00<?, ?it/s]
# house (13):   0%|          | 0/146 [00:00<?, ?it/s]
# Checking:   0%|          | 0/1575 [00:00<?, ?it/s]
# learn (14):   0%|          | 0/1104 [00:00<?, ?it/s]
# learn (14):   0%|          | 0/138 [00:00<?, ?it/s]
# learn (14):   0%|          | 0/139 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3801 [00:00<?, ?it/s]
# left (15):   0%|          | 0/2008 [00:00<?, ?it/s]
# left (15):   0%|          | 0/251 [00:00<?, ?it/s]
# left (15):   0%|          | 0/251 [00:00<?, ?it/s]
# Checking:   0%|          | 0/2100 [00:00<?, ?it/s]
# marvin (16):   0%|          | 0/1444 [00:00<?, ?it/s]
# marvin (16):   0%|          | 0/180 [00:00<?, ?it/s]
# marvin (16):   0%|          | 0/181 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3934 [00:00<?, ?it/s]
# nine (17):   0%|          | 0/2787 [00:00<?, ?it/s]
# nine (17):   0%|          | 0/348 [00:00<?, ?it/s]
# nine (17):   0%|          | 0/349 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3941 [00:00<?, ?it/s]
# no (18):   0%|          | 0/2535 [00:00<?, ?it/s]
# no (18):   0%|          | 0/316 [00:00<?, ?it/s]
# no (18):   0%|          | 0/318 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3745 [00:00<?, ?it/s]
# off (19):   0%|          | 0/1284 [00:00<?, ?it/s]
# off (19):   0%|          | 0/160 [00:00<?, ?it/s]
# off (19):   0%|          | 0/161 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3845 [00:00<?, ?it/s]
# on (20):   0%|          | 0/2463 [00:00<?, ?it/s]
# on (20):   0%|          | 0/307 [00:00<?, ?it/s]
# on (20):   0%|          | 0/309 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3890 [00:00<?, ?it/s]
# one (21):   0%|          | 0/2428 [00:00<?, ?it/s]
# one (21):   0%|          | 0/303 [00:00<?, ?it/s]
# one (21):   0%|          | 0/305 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3778 [00:00<?, ?it/s]
# right (22):   0%|          | 0/2237 [00:00<?, ?it/s]
# right (22):   0%|          | 0/279 [00:00<?, ?it/s]
# right (22):   0%|          | 0/281 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3998 [00:00<?, ?it/s]
# seven (23):   0%|          | 0/2799 [00:00<?, ?it/s]
# seven (23):   0%|          | 0/349 [00:00<?, ?it/s]
# seven (23):   0%|          | 0/351 [00:00<?, ?it/s]
# Checking:   0%|          | 0/2022 [00:00<?, ?it/s]
# sheila (24):   0%|          | 0/1386 [00:00<?, ?it/s]
# sheila (24):   0%|          | 0/173 [00:00<?, ?it/s]
# sheila (24):   0%|          | 0/174 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3860 [00:00<?, ?it/s]
# six (25):   0%|          | 0/2368 [00:00<?, ?it/s]
# six (25):   0%|          | 0/296 [00:00<?, ?it/s]
# six (25):   0%|          | 0/296 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3872 [00:00<?, ?it/s]
# stop (26):   0%|          | 0/2084 [00:00<?, ?it/s]
# stop (26):   0%|          | 0/260 [00:00<?, ?it/s]
# stop (26):   0%|          | 0/262 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3727 [00:00<?, ?it/s]
# three (27):   0%|          | 0/2351 [00:00<?, ?it/s]
# three (27):   0%|          | 0/293 [00:00<?, ?it/s]
# three (27):   0%|          | 0/295 [00:00<?, ?it/s]
# Checking:   0%|          | 0/1759 [00:00<?, ?it/s]
# tree (28):   0%|          | 0/1127 [00:00<?, ?it/s]
# tree (28):   0%|          | 0/140 [00:00<?, ?it/s]
# tree (28):   0%|          | 0/142 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3880 [00:00<?, ?it/s]
# two (29):   0%|          | 0/2249 [00:00<?, ?it/s]
# two (29):   0%|          | 0/281 [00:00<?, ?it/s]
# two (29):   0%|          | 0/282 [00:00<?, ?it/s]
# Checking:   0%|          | 0/3723 [00:00<?, ?it/s]
# up (30):   0%|          | 0/874 [00:00<?, ?it/s]
# up (30):   0%|          | 0/109 [00:00<?, ?it/s]
# up (30):   0%|          | 0/110 [00:00<?, ?it/s]
# Checking:   0%|          | 0/1592 [00:00<?, ?it/s]
# visual (31):   0%|          | 0/1151 [00:00<?, ?it/s]
# visual (31):   0%|          | 0/143 [00:00<?, ?it/s]
# visual (31):   0%|          | 0/145 [00:00<?, ?it/s]
# Checking:   0%|          | 0/2123 [00:00<?, ?it/s]
# wow (32):   0%|          | 0/1376 [00:00<?, ?it/s]
# wow (32):   0%|          | 0/172 [00:00<?, ?it/s]
# wow (32):   0%|          | 0/172 [00:00<?, ?it/s]
# Checking:   0%|          | 0/4044 [00:00<?, ?it/s]
# yes (33):   0%|          | 0/170520 [00:00<?, ?it/s]
# yes (33):   0%|          | 0/21280 [00:00<?, ?it/s]
# yes (33):   0%|          | 0/21350 [00:00<?, ?it/s]
# Checking:   0%|          | 0/4052 [00:00<?, ?it/s]
# zero (34):   0%|          | 0/2965 [00:00<?, ?it/s]
# zero (34):   0%|          | 0/370 [00:00<?, ?it/s]
# zero (34):   0%|          | 0/372 [00:00<?, ?it/s]
# 231821 29042 28927

# %%
mem("處理完所有單字後")
# Out:
# [記憶體] 處理完所有單字後: 0.21 GB

# %%
def process_background(file_name, label):
    audio = load_wav(file_name)
    if audio is None:
        return
    audio_length = len(audio)
    samples = []
    for section_start in tqdm(
        range(0, audio_length - EXPECTED_SAMPLES, 8000), desc=file_name, leave=False
    ):
        section_end = section_start + EXPECTED_SAMPLES
        section = audio[section_start:section_end].astype(np.float32)
        spectrogram = get_spectrogram(section)
        samples.append((spectrogram, label))

    for _ in tqdm(range(1000), desc="Simulated Words", leave=False):
        section_start = np.random.randint(0, audio_length - EXPECTED_SAMPLES)
        section = audio[section_start : section_start + EXPECTED_SAMPLES].astype(
            np.float32
        )

        result = np.zeros((EXPECTED_SAMPLES))
        voice_length = np.random.randint(
            int(MINIMUM_VOICE_LENGTH / 2), EXPECTED_SAMPLES
        )
        voice_start = np.random.randint(0, EXPECTED_SAMPLES - voice_length)
        hamming = np.hamming(voice_length)
        result[voice_start : voice_start + voice_length] = (
            hamming * section[voice_start : voice_start + voice_length]
        )
        spectrogram = get_spectrogram(section)
        samples.append((spectrogram, label))

    np.random.shuffle(samples)
    train_size = int(TRAIN_SIZE * len(samples))
    validation_size = int(VALIDATION_SIZE * len(samples))

    train.extend(samples[:train_size])
    validate.extend(samples[train_size : train_size + validation_size])
    test.extend(samples[train_size + validation_size :])


for file_name in tqdm(
    get_files("_background_noise_"), desc="Processing Background Noise"
):
    process_background(file_name, words.index("_background"))

print(len(train), len(test), len(validate))
# Out:
# Processing Background Noise:   0%|          | 0/6 [00:00<?, ?it/s]
# speech_data/_background_noise_/pink_noise.wav:   0%|          | 0/118 [00:00<?, ?it/s]
# Simulated Words:   0%|          | 0/1000 [00:00<?, ?it/s]
# speech_data/_background_noise_/white_noise.wav:   0%|          | 0/118 [00:00<?, ?it/s]
# Simulated Words:   0%|          | 0/1000 [00:00<?, ?it/s]
# /var/folders/9p/vrw0b6x5165fzcr_7p_j6b1r0000gp/T/ipykernel_54095/474903418.py:7: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   rate, data = wavfile.read(file_path)
# speech_data/_background_noise_/dude_miaowing.wav:   0%|          | 0/122 [00:00<?, ?it/s]
# Simulated Words:   0%|          | 0/1000 [00:00<?, ?it/s]
# speech_data/_background_noise_/doing_the_dishes.wav:   0%|          | 0/189 [00:00<?, ?it/s]
# Simulated Words:   0%|          | 0/1000 [00:00<?, ?it/s]
# speech_data/_background_noise_/exercise_bike.wav:   0%|          | 0/121 [00:00<?, ?it/s]
# Simulated Words:   0%|          | 0/1000 [00:00<?, ?it/s]
# speech_data/_background_noise_/running_tap.wav:   0%|          | 0/121 [00:00<?, ?it/s]
# Simulated Words:   0%|          | 0/1000 [00:00<?, ?it/s]
# 237249 29727 29603

# %%
mem("處理完背景噪音後")
# Out:
# [記憶體] 處理完背景噪音後: 0.22 GB

# %%
def process_problem_noise(file_name, label):
    audio = load_wav(file_name)
    if audio is None:
        return
    audio_length = len(audio)
    samples = []
    for section_start in tqdm(
        range(0, audio_length - EXPECTED_SAMPLES, 400), desc=file_name, leave=False
    ):
        section_end = section_start + EXPECTED_SAMPLES
        section = audio[section_start:section_end].astype(np.float32)
        spectrogram = get_spectrogram(section)
        samples.append((spectrogram, label))

    np.random.shuffle(samples)
    train_size = int(TRAIN_SIZE * len(samples))
    validation_size = int(VALIDATION_SIZE * len(samples))

    train.extend(samples[:train_size])
    validate.extend(samples[train_size : train_size + validation_size])
    test.extend(samples[train_size + validation_size :])


for file_name in tqdm(get_files("_problem_noise_"), desc="Processing problem noise"):
    process_problem_noise(file_name, words.index("_background"))
# Out:
# Processing problem noise: 0it [00:00, ?it/s]

# %%
def process_mar_sounds(file_name, label):
    audio = load_wav(file_name)
    if audio is None:
        return
    audio_length = len(audio)
    samples = []
    for section_start in tqdm(
        range(0, audio_length - EXPECTED_SAMPLES, 4000), desc=file_name, leave=False
    ):
        section_end = section_start + EXPECTED_SAMPLES
        section = audio[section_start:section_end].astype(np.float32)
        section = section - np.mean(section)
        peak = np.max(np.abs(section))
        if peak > 0:
            section = section / peak

        background_volume = np.random.uniform(0, 0.1)
        background_files = get_files("_background_noise_")
        background_file = np.random.choice(background_files)
        background = load_wav(background_file)
        if background is not None and len(background) >= EXPECTED_SAMPLES:
            bg_start = np.random.randint(0, len(background) - EXPECTED_SAMPLES)
            bg = background[bg_start : bg_start + EXPECTED_SAMPLES].astype(np.float32)
            bg = bg - np.mean(bg)
            bg_peak = np.max(np.abs(bg))
            if bg_peak > 0:
                bg = bg / bg_peak
            section = section + background_volume * bg

        spectrogram = get_spectrogram(section)
        samples.append((spectrogram, label))

    np.random.shuffle(samples)
    train_size = int(TRAIN_SIZE * len(samples))
    validation_size = int(VALIDATION_SIZE * len(samples))

    train.extend(samples[:train_size])
    validate.extend(samples[train_size : train_size + validation_size])
    test.extend(samples[train_size + validation_size :])


for file_name in tqdm(get_files("_mar_sounds_"), desc="Processing problem noise"):
    process_mar_sounds(file_name, words.index("_background"))
# Out:
# Processing problem noise: 0it [00:00, ?it/s]

# %%
print(len(train), len(test), len(validate))
# Out:
# 237249 29727 29603

# %%
# randomise the training samples
np.random.shuffle(train)

# %%
mem("shuffle 後")
# Out:
# [記憶體] shuffle 後: 0.24 GB

# %%
X_train, Y_train = zip(*train)
X_validate, Y_validate = zip(*validate)
X_test, Y_test = zip(*test)

# %%
# save the computed data
np.savez_compressed("training_spectrogram.npz", X=X_train, Y=Y_train)
print("Saved training data")
np.savez_compressed("validation_spectrogram.npz", X=X_validate, Y=Y_validate)
print("Saved validation data")
np.savez_compressed("test_spectrogram.npz", X=X_test, Y=Y_test)
print("Saved test data")
# Out:
# Saved training data
# Saved validation data
# Saved test data

# %%
mem("儲存 npz 後")
# Out:
# [記憶體] 儲存 npz 後: 1.20 GB

# %%
# get the width and height of the spectrogram "image"
IMG_WIDTH = X_train[0].shape[0]
IMG_HEIGHT = X_train[0].shape[1]

# %%
def plot_images2(images_arr, imageWidth, imageHeight):
    fig, axes = plt.subplots(5, 5, figsize=(10, 20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(np.reshape(img, (imageWidth, imageHeight)))
        ax.axis("off")
    plt.tight_layout()
    plt.show()

# %%
word_index = words.index("yes")

X_happys = np.array(X_train)[np.array(Y_train) == word_index]
Y_happys = np.array(Y_train)[np.array(Y_train) == word_index]
plot_images2(X_happys[:20], IMG_WIDTH, IMG_HEIGHT)
print(Y_happys[:20])
# Out:
# [33 33 33 33 33 33 33 33 33 33 33 33 33 33 33 33 33 33 33 33]
